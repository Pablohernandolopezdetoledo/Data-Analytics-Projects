# %%
import pandas as pd
import numpy as np

# %%
fm_2020 = pd.read_csv('Downloads/datafm20.csv.zip')

# %% [markdown]
# 14k+ FM20 players, 60+ attributes extracted from the latest FM20 database
#
# https://www.kaggle.com/datasets/ktyptorio/football-manager-2020

# %%
fm_2020
# Out:
#         Unnamed: 0                  Name                Position         Club  \
# 0                0          Lionel Messi         AM (RC), ST (C)    Barcelona
# 1                1     Cristiano Ronaldo         AM (RL), ST (C)     Juventus
# 2                2        Kylian Mbapp̩         AM (RL), ST (C)     Paris SG
# 3                3          Manuel Neuer                      GK    FC Bayern
# 4                4                Neymar  M (L), AM (LC), ST (C)     Paris SG
# ...            ...                   ...                     ...          ...
# 144745      144745          Yuan Jinxing                  ST (C)      Unknown
# 144746      144746  Aizudin Abdul Rahman                   M (C)         BSRC
# 144747      144747    Berlin Jean-Gilles                  ST (C)  CS Monteuil
# 144748      144748    Frederik van Hauen                   M (C)   Skovshoved
# 144749      144749         Hui Kim Yeung                   M (C)      Freemen
#
# ...

# %% [markdown]
# This dataset contains football-related data covering the Top5 leagues in Europe from 2014-2020. It is structured like a relational database, which makes it easy to work with, regardless of the problem you want so solve.
#
# https://www.kaggle.com/datasets/technika148/football-database?select=games.csv
